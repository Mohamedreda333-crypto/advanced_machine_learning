# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:/Users/PC/Desktop/Data Preprocessing/used_car_sales.csv",parse_dates=["Purchased Date","Sold Date"])
df
# Out:
#           ID Distributor Name        Location  Car Name Manufacturer Name  \
# 0     O2KE17          Carmudi      California  Fortuner            Toyota
# 1     EPMPC8        Carousell    Philadelphia     Creta           Hyundai
# 2     SQKXAP          Carsome  North Carolina   Scorpio          Mahindra
# 3     PWP2QK          Trivett  North Carolina     Plato             Prazo
# 4     FNDDKM            Zupps        Portland     Dzire            Maruti
# ...      ...              ...             ...       ...               ...
# 9995  ZHLCSG              APE           Texas     Yodha              Tata
# 9996  2BJE0Y          Carsome        Portland   Scorpio          Mahindra
# 9997  4OVJ83            Trust  North Carolina    Seltos               Kia
# 9998  M2ECXT          Carsome         Detroit     Swift            Maruti
# 9999  28W445              Olx        Portland     Swift            Maruti
#
#          Car Type  Color    Gearbox  Number of Seats  Number of Doors  ...  \
# ...

# %%
"""
1) ID: Unique identifier for each record.

2) Distributor Name: Name of the car distributor.

3) Location: Location of the distributors office.

4) Car Name: The specific name of the car.

5) Manufacturer Name: Name of the cars manufacturer.

6) Car Type: Type of car (e.g., Sedan, SUV, Hatchback, etc.).

7) Color: Cars color.

8) Gearbox: Type of gearbox (e.g., Manual, Automatic).

9) Number of Seats: Total number of seats in the car.

10) Number of Doors: Number of doors in the car.

11) Energy: Fuel type used by the car (e.g., Petrol, Diesel, Electric).

12) Manufactured Year: Year the car was manufactured.

13) Price-$: Listed price of the car in USD.

14) Mileage-KM: Total kilometers the car has traveled.

15) Engine Power-HP: Horsepower (HP) of the car engine.

16) Purchased Date: Date the distributor purchased the car.

17) Car Sale Status: Indicates whether the car was sold to a customer (Sold/Not Sold).

18) Sold Date: Date the car was sold to a customer.

19) Purchased Price-$: Purchase price paid by the distributor.

20) Sold Price-$: Sale price paid by the customer.

21) Margin-%: Percentage margin earned by the distributor.

22) Sales Agent Name: Name of the sales agent who closed the deal.

23) Sales Rating: Rating given to the sales agent by the distributor.

24) Sales Commission-$: Commission paid to the sales agent by the distributor.

25) Feedback: Customer feedback on the sales experience.
"""
df.head()
# Out:
#        ID Distributor Name        Location  Car Name Manufacturer Name  \
# 0  O2KE17          Carmudi      California  Fortuner            Toyota
# 1  EPMPC8        Carousell    Philadelphia     Creta           Hyundai
# 2  SQKXAP          Carsome  North Carolina   Scorpio          Mahindra
# 3  PWP2QK          Trivett  North Carolina     Plato             Prazo
# 4  FNDDKM            Zupps        Portland     Dzire            Maruti
#
#       Car Type Color    Gearbox  Number of Seats  Number of Doors  ...  \
# 0          SUV  Gray  Automatic                8                5  ...
# 1    Hatchback  Blue  Automatic                5                5  ...
# 2          SUV  Gray  Automatic                5                5  ...
# 3  Convertible  Gray  Automatic                2                2  ...
# 4        Sedan   Red  Automatic                5                5  ...
#
#   Purchased Date  Car Sale Status  Sold Date  Purchased Price-$  Sold Price-$  \
# ...

# %%
df.tail()
# Out:
#           ID Distributor Name        Location Car Name Manufacturer Name  \
# 9995  ZHLCSG              APE           Texas    Yodha              Tata
# 9996  2BJE0Y          Carsome        Portland  Scorpio          Mahindra
# 9997  4OVJ83            Trust  North Carolina   Seltos               Kia
# 9998  M2ECXT          Carsome         Detroit    Swift            Maruti
# 9999  28W445              Olx        Portland    Swift            Maruti
#
#        Car Type  Color    Gearbox  Number of Seats  Number of Doors  ...  \
# 9995      Truck   Blue     Manual                3                2  ...
# 9996        SUV  Black  Automatic                5                5  ...
# 9997  Hatchback  Black  Automatic                5                5  ...
# 9998      Sedan  Black  Automatic                5                4  ...
# 9999      Sedan  White  Automatic                5                4  ...
#
#      Purchased Date  Car Sale Status  Sold Date  Purchased Price-$  \
# ...

# %%
list(df.columns)
# Out:
# ['ID',
#  'Distributor Name',
#  'Location',
#  'Car Name',
#  'Manufacturer Name',
#  'Car Type',
#  'Color',
#  'Gearbox',
#  'Number of Seats',
#  'Number of Doors',
#  'Energy',
#  'Manufactured Year',
#  'Price-$',
#  'Mileage-KM',
#  'Engine Power-HP',
#  'Purchased Date',
#  'Car Sale Status',
#  'Sold Date',
#  'Purchased Price-$',
#  'Sold Price-$',
#  'Margin-%',
#  'Sales Agent Name',
#  'Sales Rating',
#  'Sales Commission-$',
#  'Feedback']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  10000 non-null  object
#  1   Distributor Name    10000 non-null  object
#  2   Location            10000 non-null  object
#  3   Car Name            10000 non-null  object
#  4   Manufacturer Name   10000 non-null  object
#  5   Car Type            10000 non-null  object
#  6   Color               10000 non-null  object
#  7   Gearbox             10000 non-null  object
#  8   Number of Seats     10000 non-null  int64
#  9   Number of Doors     10000 non-null  int64
#  10  Energy              10000 non-null  object
#  11  Manufactured Year   10000 non-null  int64
#  12  Price-$             10000 non-null  int64
#  13  Mileage-KM          10000 non-null  int64
#  14  Engine Power-HP     10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#        Number of Seats  Number of Doors  Manufactured Year       Price-$  \
# count     10000.000000     10000.000000       10000.000000  10000.000000
# mean          4.786000         4.081000        2019.525200   7975.100000
# min           2.000000         2.000000        2015.000000   6000.000000
# 25%           4.000000         3.000000        2017.000000   7200.000000
# 50%           5.000000         5.000000        2020.000000   7900.000000
# 75%           5.000000         5.000000        2022.000000   8700.000000
# max           8.000000         5.000000        2024.000000  10900.000000
# std           1.466499         1.266807           2.886693   1018.829618
#
#          Mileage-KM  Engine Power-HP                 Purchased Date  \
# count  10000.000000     10000.000000                          10000
# mean   45497.531800       143.344700  2020-01-09 21:10:30.719999744
# min     1000.000000       100.000000            2015-01-01 00:00:00
# ...

# %%
Q1 = df["Purchased Price-$"].quantile(0.25)
Q3 = df["Purchased Price-$"].quantile(0.75)
IQR = Q3 - Q1
upper = Q3 + 1.5 * IQR
upper
# Out:
# np.float64(9797.625)

# %%
df[df["Purchased Price-$"] > upper]
# Out:
#           ID Distributor Name        Location Car Name Manufacturer Name  \
# 991   CLF8IF            Nufor  North Carolina    Plato             Prazo
# 1206  WPSFSS              Olx         Florida    Plato             Prazo
# 1248  238HA3              Oto    Philadelphia    Plato             Prazo
# 1357  SF1B7N              Olx        Oklahoma    Plato             Prazo
# 1469  MANQLA             Knox        San Jose    Plato             Prazo
# 1516  44LNQ1         Automart    Philadelphia    Plato             Prazo
# 1649  A7J5Q7          Skipper  North Carolina    Plato             Prazo
# 2282  P44UDL              Oto        Columbus    Plato             Prazo
# 2463  PA99HD              APE           Texas    Plato             Prazo
# 2539  XX23Z6            Zupps          Denver    Plato             Prazo
# 3100  YHUMYA          Trivett          Denver    Plato             Prazo
# 3504  KLD4NY              Olx          Tucson    Plato             Prazo
# ...

# %%
x = df[df["Purchased Price-$"] > upper]
x.shape
# Out:
# (36, 25)

# %%
df[df["Manufacturer Name"] == "Prazo"]
# Out:
#           ID Distributor Name        Location Car Name Manufacturer Name  \
# 3     PWP2QK          Trivett  North Carolina    Plato             Prazo
# 56    8XWHPE           Cars24         Madison    Plato             Prazo
# 59    1JZYN5            Nufor            Utah    Plato             Prazo
# 94    1GJOBW            Motor      California    Plato             Prazo
# 98    ALXRLJ              Olx  North Carolina    Plato             Prazo
# ...      ...              ...             ...      ...               ...
# 9883  V1OAPD              Oto         Florida    Plato             Prazo
# 9893  AVN43U            Carro        Columbus    Plato             Prazo
# 9943  U31JXQ              Ahg         Detroit    Plato             Prazo
# 9947  NHXKCD           Carmix         Florida    Plato             Prazo
# 9960  T3DJJF            Trust       Tennessee    Plato             Prazo
#
#          Car Type  Color    Gearbox  Number of Seats  Number of Doors  ...  \
# ...

# %%
df["Purchased Price-$"][df["Manufacturer Name"] == "Prazo"].mean()
# Out:
# np.float64(8399.902941176471)

# %%
df.groupby("Manufacturer Name").get_group("Prazo")["Purchased Price-$"].agg("mean")
df.groupby("Manufacturer Name").get_group("Prazo")["Purchased Price-$"].mean()
# Out:
# np.float64(8399.902941176471)

# %%
df.pivot_table(index="Manufacturer Name",values="Purchased Price-$",aggfunc="mean")
# prazo - Mahindra - Renault - Toyota - Tata - Maruti - Hyundai - Kia
# Out:
#                    Purchased Price-$
# Manufacturer Name
# Hyundai                  5870.966359
# Kia                      5813.161708
# Mahindra                 7324.031289
# Maruti                   6159.878480
# Prazo                    8399.902941
# Renault                  7299.477876
# Tata                     6827.349398
# Toyota                   7111.743060

# %%
x = df.pivot_table(index="Manufacturer Name",values="Purchased Price-$",aggfunc="mean")
x.sort_values(by = "Purchased Price-$",ascending=False)
# Out:
#                    Purchased Price-$
# Manufacturer Name
# Prazo                    8399.902941
# Mahindra                 7324.031289
# Renault                  7299.477876
# Toyota                   7111.743060
# Tata                     6827.349398
# Maruti                   6159.878480
# Hyundai                  5870.966359
# Kia                      5813.161708

# %%
df[["Engine Power-HP"]]
# Out:
#       Engine Power-HP
# 0                 200
# 1                 113
# 2                 120
# 3                 250
# 4                 100
# ...               ...
# 9995              100
# 9996              120
# 9997              150
# 9998              115
# 9999              115
#
# [10000 rows x 1 columns]

# %%
df.groupby(["Manufacturer Name"])["Engine Power-HP"].mean()
# Out:
# Manufacturer Name
# Hyundai     116.583113
# Kia         150.000000
# Mahindra    125.056320
# Maruti      105.917808
# Prazo       250.000000
# Renault     175.000000
# Tata        100.000000
# Toyota      200.000000
# Name: Engine Power-HP, dtype: float64

# %%
df[["Engine Power-HP"]].value_counts()
# Out:
# Engine Power-HP
# 120                1566
# 100                1553
# 200                1549
# 103                 809
# 130                 808
# 175                 791
# 150                 773
# 113                 740
# 115                 731
# 250                 680
# Name: count, dtype: int64

# %%
df.describe(include = "O")
# Out:
#             ID Distributor Name        Location Car Name Manufacturer Name  \
# count    10000            10000           10000    10000             10000
# unique   10000               21              17       13                 8
# top     G0K5HM           Cars24  North Carolina    Yodha            Maruti
# freq         1              520            1075      830              2263
#
#        Car Type  Color    Gearbox  Energy Car Sale Status Sales Agent Name  \
# count     10000  10000      10000   10000           10000            10000
# unique        5      5          2       4               2               27
# top         SUV   Blue  Automatic  Hybrid         Un Sold          Krishna
# freq       3167   2353       5093    2536            7834              410
#
#          Feedback
# count       10000
# unique          4
# top     Excellent
# freq         4117

# %%
sold = df[df["Car Sale Status"] == "Sold"]

# %%
sold["Purchased Price-$"].sum()
# Out:
# np.int64(14600544)

# %%
sold["Sold Price-$"].sum()
# Out:
# np.int64(14877761)

# %%
Magin = (sold["Sold Price-$"].sum()) -  (sold["Purchased Price-$"].sum())
Magin
# Out:
# np.int64(277217)

# %%
sold["Purchased Date"].min()
# Out:
# Timestamp('2015-01-03 00:00:00')

# %%
sold["Sold Date"].max()
# Out:
# Timestamp('2025-02-16 00:00:00')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset="ID").sum()
# Out:
# np.int64(0)

# %%
null = df.isnull().sum()
null
# Out:
# ID                    0
# Distributor Name      0
# Location              0
# Car Name              0
# Manufacturer Name     0
# Car Type              0
# Color                 0
# Gearbox               0
# Number of Seats       0
# Number of Doors       0
# Energy                0
# Manufactured Year     0
# Price-$               0
# Mileage-KM            0
# Engine Power-HP       0
# Purchased Date        0
# Car Sale Status       0
# Sold Date             0
# Purchased Price-$     0
# Sold Price-$          0
# Margin-%              0
# Sales Agent Name      0
# Sales Rating          0
# Sales Commission-$    0
# Feedback              0
# dtype: int64

# %%
df["Purchased Price-$"].agg(["mean","min","max"])
# Out:
# mean     6720.6177
# min      4015.0000
# max     10383.0000
# Name: Purchased Price-$, dtype: float64

# %%
df[df["Purchased Price-$"] == df["Purchased Price-$"].min()]
# Out:
#           ID Distributor Name    Location Car Name Manufacturer Name  \
# 4943  ABRLPN            Carro  California   Etriga            Maruti
#
#        Car Type Color    Gearbox  Number of Seats  Number of Doors  ...  \
# 4943  Hatchback   Red  Automatic                4                5  ...
#
#      Purchased Date  Car Sale Status  Sold Date  Purchased Price-$  \
# 4943     2020-05-29          Un Sold 1970-01-01               4015
#
#       Sold Price-$ Margin-% Sales Agent Name Sales Rating  Sales Commission-$  \
# 4943             0        0          Shruthi            4                   0
#
#        Feedback
# 4943  Excellent
#
# [1 rows x 25 columns]

# %%
df[df["Purchased Price-$"] == df["Purchased Price-$"].max()]
# Out:
#           ID Distributor Name  Location Car Name Manufacturer Name  \
# 5978  XK79H0           Marchi  San Jose    Plato             Prazo
#
#          Car Type Color Gearbox  Number of Seats  Number of Doors  ...  \
# 5978  Convertible  Blue  Manual                2                2  ...
#
#      Purchased Date  Car Sale Status  Sold Date  Purchased Price-$  \
# 5978     2016-04-28          Un Sold 1970-01-01              10383
#
#       Sold Price-$ Margin-% Sales Agent Name Sales Rating  Sales Commission-$  \
# 5978             0        0           Swathi            1                   0
#
#       Feedback
# 5978      Poor
#
# [1 rows x 25 columns]

# %%
df["Car Sale Status"].replace({"Sold" : 1 , "Un Sold" : 0},inplace = True)

# %%
df.head()
# Out:
#        ID Distributor Name        Location  Car Name Manufacturer Name  \
# 0  O2KE17          Carmudi      California  Fortuner            Toyota
# 1  EPMPC8        Carousell    Philadelphia     Creta           Hyundai
# 2  SQKXAP          Carsome  North Carolina   Scorpio          Mahindra
# 3  PWP2QK          Trivett  North Carolina     Plato             Prazo
# 4  FNDDKM            Zupps        Portland     Dzire            Maruti
#
#       Car Type Color    Gearbox  Number of Seats  Number of Doors  ...  \
# 0          SUV  Gray  Automatic                8                5  ...
# 1    Hatchback  Blue  Automatic                5                5  ...
# 2          SUV  Gray  Automatic                5                5  ...
# 3  Convertible  Gray  Automatic                2                2  ...
# 4        Sedan   Red  Automatic                5                5  ...
#
#   Purchased Date  Car Sale Status  Sold Date  Purchased Price-$  Sold Price-$  \
# ...

# %%
df["Car Sale Status"]
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Car Sale Status, Length: 10000, dtype: int64

# %%
df["Feedback"].nunique()
# Out:
# 4

# %%
df["Feedback"].value_counts()
# Out:
# Feedback
# Excellent    4117
# Good         2944
# Average      2011
# Poor          928
# Name: count, dtype: int64

# %%
df["Feedback"].replace({"Poor" : 0 ,"Average" : 1 ,"Good" : 2 , "Excellent" : 3}, inplace = True)

# %%
df.head()
# Out:
#        ID Distributor Name        Location  Car Name Manufacturer Name  \
# 0  O2KE17          Carmudi      California  Fortuner            Toyota
# 1  EPMPC8        Carousell    Philadelphia     Creta           Hyundai
# 2  SQKXAP          Carsome  North Carolina   Scorpio          Mahindra
# 3  PWP2QK          Trivett  North Carolina     Plato             Prazo
# 4  FNDDKM            Zupps        Portland     Dzire            Maruti
#
#       Car Type Color    Gearbox  Number of Seats  Number of Doors  ...  \
# 0          SUV  Gray  Automatic                8                5  ...
# 1    Hatchback  Blue  Automatic                5                5  ...
# 2          SUV  Gray  Automatic                5                5  ...
# 3  Convertible  Gray  Automatic                2                2  ...
# 4        Sedan   Red  Automatic                5                5  ...
#
#   Purchased Date  Car Sale Status  Sold Date  Purchased Price-$  Sold Price-$  \
# ...

# %%
df[["Feedback"]]
# Out:
#       Feedback
# 0            1
# 1            2
# 2            2
# 3            1
# 4            0
# ...        ...
# 9995         3
# 9996         3
# 9997         0
# 9998         1
# 9999         0
#
# [10000 rows x 1 columns]

# %%
df["Days to sell"] = df["Sold Date"] - df["Purchased Date"]

# %%
df.head(10)
# Out:
#        ID Distributor Name        Location  Car Name Manufacturer Name  \
# 0  O2KE17          Carmudi      California  Fortuner            Toyota
# 1  EPMPC8        Carousell    Philadelphia     Creta           Hyundai
# 2  SQKXAP          Carsome  North Carolina   Scorpio          Mahindra
# 3  PWP2QK          Trivett  North Carolina     Plato             Prazo
# 4  FNDDKM            Zupps        Portland     Dzire            Maruti
# 5  I5D584            Zupps          Denver  Fortuner            Toyota
# 6  KPRE75           Cars24        New York      Thar          Mahindra
# 7  8C1O0B              Ahg          Denver    Etriga            Maruti
# 8  KCVVNQ              Olx         Detroit     Yodha              Tata
# 9  HGW6RK            Nufor       Tennessee     Creta           Hyundai
#
#       Car Type  Color    Gearbox  Number of Seats  Number of Doors  ...  \
# 0          SUV   Gray  Automatic                8                5  ...
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Distributor Name', 'Location', 'Car Name', 'Manufacturer Name',
#        'Car Type', 'Color', 'Gearbox', 'Number of Seats', 'Number of Doors',
#        'Energy', 'Manufactured Year', 'Price-$', 'Mileage-KM',
#        'Engine Power-HP', 'Purchased Date', 'Car Sale Status', 'Sold Date',
#        'Purchased Price-$', 'Sold Price-$', 'Margin-%', 'Sales Agent Name',
#        'Sales Rating', 'Sales Commission-$', 'Feedback', 'Days to sell'],
#       dtype='object')

# %%
df.loc[df["Car Sale Status"] == 0 , "Days to sell"] = 0

# %%
df.head(10)
# Out:
#        ID Distributor Name        Location  Car Name Manufacturer Name  \
# 0  O2KE17          Carmudi      California  Fortuner            Toyota
# 1  EPMPC8        Carousell    Philadelphia     Creta           Hyundai
# 2  SQKXAP          Carsome  North Carolina   Scorpio          Mahindra
# 3  PWP2QK          Trivett  North Carolina     Plato             Prazo
# 4  FNDDKM            Zupps        Portland     Dzire            Maruti
# 5  I5D584            Zupps          Denver  Fortuner            Toyota
# 6  KPRE75           Cars24        New York      Thar          Mahindra
# 7  8C1O0B              Ahg          Denver    Etriga            Maruti
# 8  KCVVNQ              Olx         Detroit     Yodha              Tata
# 9  HGW6RK            Nufor       Tennessee     Creta           Hyundai
#
#       Car Type  Color    Gearbox  Number of Seats  Number of Doors  ...  \
# 0          SUV   Gray  Automatic                8                5  ...
# ...

# %%
df.sample(n=5)
# Out:
#           ID Distributor Name        Location Car Name Manufacturer Name  \
# 813   P0W9PF            Zupps         Florida    Creta           Hyundai
# 1454  7MEDOD             Knox            Utah    Swift            Maruti
# 2896  XNBTIB              Olx  North Carolina  Scorpio          Mahindra
# 4341  AZVKA8          Trivett         Chicago     Thar          Mahindra
# 5695  HBQHLR              Ahg  North Carolina   Seltos               Kia
#
#        Car Type  Color    Gearbox  Number of Seats  Number of Doors  ...  \
# 813   Hatchback    Red     Manual                5                5  ...
# 1454      Sedan   Blue     Manual                5                4  ...
# 2896        SUV   Blue  Automatic                5                5  ...
# 4341        SUV  White  Automatic                5                3  ...
# 5695  Hatchback   Blue     Manual                5                5  ...
#
#      Car Sale Status  Sold Date  Purchased Price-$  Sold Price-$  Margin-%  \
# ...

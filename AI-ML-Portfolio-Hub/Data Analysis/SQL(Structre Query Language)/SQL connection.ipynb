# %%
! pip install pyodbc pandas
# Out:
# ...
#   Obtaining dependency information for pyodbc from https://files.pythonhosted.org/packages/7c/6b/f0ad7d8a535d58f35f375ffbf367c68d0ec54452a431d23b0ebee4cd44c6/pyodbc-5.2.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/68.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/68.9 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/68.9 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/68.9 kB ? eta -:--:--
#    ----------------------- ---------------- 41.0/68.9 kB 245.8 kB/s eta 0:00:01
#    ---------------------------------------- 68.9/68.9 kB 340.9 kB/s eta 0:00:00
# ...

# %%
import pyodbc



connection = pyodbc.connect(
       'DRIVER={SQL Server};''SERVER=PC-1;' 'DATABASE=AdventureWorksLT2022;' 'Trusted_connection =yes'

)

# Create a cursor object to execute queries
cursor = connection.cursor()

print("Connection successful!")
# Out:
# Connection successful!

# %%
query = "SELECT TOP 10 CustomerID, FirstName, LastName FROM SalesLT.Customer"
cursor.execute(query)

# %%
# Fetch and print results
for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'Orlando', 'Gee')
# (2, 'Keith', 'Harris')
# (3, 'Donna', 'Carreras')
# (4, 'Janet', 'Gates')
# (5, 'Lucy', 'Harrington')
# (6, 'Rosmarie', 'Carroll')
# (7, 'Dominic', 'Gash')
# (10, 'Kathleen', 'Garza')
# (11, 'Katherine', 'Harding')
# (12, 'Johnny', 'Caprio')

# %%
import pandas as pd

# Example query
query = "SELECT TOP 10 CustomerID, FirstName, LastName FROM SalesLT.Customer"

# Load data into a Pandas DataFrame
# TO parameters(query,connection)
df = pd.read_sql_query(query, connection)

# Display the DataFrame
print(df)
# Out:
#    CustomerID  FirstName    LastName
# 0           1    Orlando         Gee
# 1           2      Keith      Harris
# 2           3      Donna    Carreras
# 3           4      Janet       Gates
# 4           5       Lucy  Harrington
# 5           6   Rosmarie     Carroll
# 6           7    Dominic        Gash
# 7          10   Kathleen       Garza
# 8          11  Katherine     Harding
# 9          12     Johnny      Caprio
# C:\Users\El-Wattaneya\AppData\Local\Temp\ipykernel_9412\697503929.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
df.head()
# Out:
#    CustomerID FirstName    LastName
# 0           1   Orlando         Gee
# 1           2     Keith      Harris
# 2           3     Donna    Carreras
# 3           4     Janet       Gates
# 4           5      Lucy  Harrington

# %%
query = """
SELECT 
    c.CustomerID, 
    c.FirstName + ' ' + c.LastName AS CustomerName, 
    SUM(sod.LineTotal) AS TotalRevenue
FROM SalesLT.Customer c
JOIN SalesLT.SalesOrderHeader soh ON c.CustomerID = soh.CustomerID
JOIN SalesLT.SalesOrderDetail sod ON soh.SalesOrderID = sod.SalesOrderID
GROUP BY c.CustomerID, c.FirstName, c.LastName
ORDER BY TotalRevenue DESC;
"""

# Execute and load into DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
# C:\Users\El-Wattaneya\AppData\Local\Temp\ipykernel_9412\2387402280.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#     CustomerID          CustomerName  TotalRevenue
# 0        29736       Terry Eminhizer  89869.276314
# 1        30050  Krishna Sunkammurali  79589.616024
# 2        29546      Christopher Beck  74160.228000
# 3        29957             Kevin Liu  65683.367986
# 4        29796            Jon Grande  65123.463418
# 5        29929         Jeffrey Kurtz  59894.209200
# 6        29932        Rebecca Laszlo  53248.692000
# 7        29660          Anthony Chor  47848.026000
# 8        29938        Frank Campbell  34118.535600
# 9        29485        Catherine Abel  33319.986000
# 10       30113        Raja Venugopal  29923.008000
# ...

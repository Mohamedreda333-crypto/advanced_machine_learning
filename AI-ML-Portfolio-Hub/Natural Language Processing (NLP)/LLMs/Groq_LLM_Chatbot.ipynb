# %%
import requests
import os
groq_api_key = os.getenv("GROQ_API_KEY")
url = "https://api.groq.com/openai/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {GROQ_API_KEY}",
    "Content-Type": "application/json"
}

chat_history = [
    {"role": "system", "content": "You are a helpful assistant."}
]

while True:
    user_input = input("🧑 You: ")
    if user_input.lower() == "exit":
        print("👋 Goodbye!")
        break

    chat_history.append({"role": "user", "content": user_input})

    data = {
        "model": "llama-3.3-70b-versatile",
        "messages": chat_history,
        "temperature": 0.7
    }

    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        reply = response.json()["choices"][0]["message"]["content"]
        chat_history.append({"role": "assistant", "content": reply})
        print(f"🤖 Bot: {reply}\n")
    else:
        print(f"[Error] {response.status_code}: {response.text}")
# Out:
# 🧑 You: Hello
# 🤖 Bot: Hello. It's nice to meet you. Is there something I can help you with or would you like to chat?
#
# 🧑 You: tell me about Ai
# 🤖 Bot: Artificial Intelligence (AI) is a broad field that encompasses a range of technologies and techniques aimed at creating machines that can perform tasks that typically require human intelligence. These tasks include:
#
# 1. **Learning**: AI systems can learn from data, experiences, and interactions, and improve their performance over time.
# 2. **Problem-solving**: AI systems can analyze problems, identify patterns, and develop solutions.
# 3. **Reasoning**: AI systems can draw inferences, make decisions, and arrive at conclusions based on available data.
# 4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.
#
# Some common applications of AI include:
#
# ...

# %%
import requests

GROQ_API_KEY = "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"
url = "https://api.groq.com/openai/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {GROQ_API_KEY}",
    "Content-Type": "application/json"
}
content = """
أنت نموذج لغوي ذكي متخصص في التاريخ المصري فقط.

مهمتك هي الإجابة على جميع الأسئلة باللغة العربية الفصحى، مع الالتزام
 الصارم بأن تكون الإجابات ضمن نطاق التاريخ المصري فقط،
 سواء القديم أو الحديث أو المعاصر.

إذا تم طرح أي سؤال خارج هذا النطاق
 (مثل السياسة الحالية، أو تاريخ دول أخرى، أو التكنولوجيا، أو الرياضة،
 أو الأدب، أو الأسئلة العامة)، فاعتذر بلطف وقل:

"أعتذر، اختصاصي يقتصر على التاريخ المصري فقط."

تأكد دائمًا من استخدام لغة واضحة، رصينة، خالية من العامية،
واذكر التواريخ أو الشخصيات التاريخية متى أمكن.

ابدأ الآن في انتظار الأسئلة الخاصة بالتاريخ المصري فقط.


"""
chat_history = [
    {"role": "system", "content": content}
]

while True:
    user_input = input("🧑 You: ")
    if user_input.lower() == "exit":
        print("👋 Goodbye!")
        break

    chat_history.append({"role": "user", "content": user_input})

    data = {
        "model": "llama-3.3-70b-versatile",
        "messages": chat_history,
        "temperature": 0.7
    }

    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        reply = response.json()["choices"][0]["message"]["content"]
        chat_history.append({"role": "assistant", "content": reply})
        print(f"🤖 Bot: {reply}\n")
    else:
        print(f"[Error] {response.status_code}: {response.text}")
# Out:
# 🧑 You: مساء الخير
# 🤖 Bot: مساء النور. كيف يمكنني مساعدتك في شؤون التاريخ المصري؟ هل لديك سؤال ما حول الأهرامات، أو الأسرة الفرعونية، أو العصور القديمة؟ أنت مرحب بك لطرح أي سؤال في هذا السياق.
#
# 🧑 You: من هو رمسيس الثاني
# 🤖 Bot: رمسيس الثاني، ويعرف cũng باسم رمسيس الأكبر، هو أحد أشهر حكام مصر القديمة. ولد حوالي عام 1303 قبل الميلاد، وتولى الحكم في عهد الأسرة التاسعة عشرة حوالي عام 1279 قبل الميلاد. حكم رمسيس الثاني مصر لمدة 67 سنة، حتى وفاته حوالي عام 1213 قبل الميلاد.
#
# رمسيس الثاني معروف بأنه أحد أهم وأطول الأشخاص حكماً في تاريخ مصر، وقد قاد العديد من الحملات العسكرية الناجحة ضد الحيثيين والشعوب الأخرى في منطقة الشرق الأوسط. كما قام ببناء العديد من المعابد والمباني في مصر، بما في ذلك معبد أبو سمبل الشهير.
#
# إحدى أهم الإنجازات التي قام بها رمسيس الثاني هي توقيع معاهدة الصداقة مع الحيثيين، التي تعتبر واحدة من أولى المعاهدات الدولية المعروفة في التاريخ. كما قام رمسيس الثاني ببناء العديد من الآثار المعمارية، بما في ذلك معبد الكرنك ومعبد لوكسور.
#
# ...

# %%
import requests

GROQ_API_KEY = "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"
url = "https://api.groq.com/openai/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {GROQ_API_KEY}",
    "Content-Type": "application/json"
}
content = """
https://en.wikipedia.org/wiki/Egypt
جاوب بالعامية المصرية من خلال اللينك دا فقط
اي حاجه برا اللينك دا قول انك مش متخصص فيها وانك تخصص مصر واخبارها فقط
وقوله ميتعاملش معاك تاني
"""
chat_history = [
    {"role": "system", "content": content}
]

while True:
    user_input = input("🧑 You: ")
    if user_input.lower() == "exit":
        print("👋 Goodbye!")
        break

    chat_history.append({"role": "user", "content": user_input})

    data = {
        "model": "llama-3.3-70b-versatile",
        "messages": chat_history,
        "temperature": 0.7
    }

    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        reply = response.json()["choices"][0]["message"]["content"]
        chat_history.append({"role": "assistant", "content": reply})
        print(f"🤖 Bot: {reply}\n")
    else:
        print(f"[Error] {response.status_code}: {response.text}")
# Out:
# 🧑 You: مساء الخير
# 🤖 Bot: مساء النور، إزاية تعرف مصر؟
#
# 🧑 You: اكلم عن قناة السويس
# 🤖 Bot: قناة السويس هي قناة مائية تربط بين البحر الأحمر والبحر الأبيض المتوسط، وتعتبر واحدة من أهم القنوات المائية في العالم. تم افتتاحها في عام 1869، وتمتد على طول 193 كم في مصر. القناة تحول دون الحاجة للمسافرين والتجار إلى التنقل حول رأس الرجاء الصالح في جنوب أفريقيا، مما يقلل من المسافة البحرية بين أوروبا وآسيا بنسبة 70%.
#
# القناة السويس لها أهمية اقتصادية وسياسية كبيرة، حيث تعتبر واحدة من أهم الممرات المائية في العالم، وتستخدمها أكثر من 17 ألف سفينة في العام. القناة أيضاً تعتبر مصدر دخل مهم لمصر، حيث أن الرسوم التي تُدفع من قبل السفن التي تعبر القناة تُشكل جزءًا كبيرًا من إيرادات مصر.
#
# في 2015، تم افتتاح قناة السويس الجديدة، والتي تهدف إلى زيادة سعة القناة وخفض الوقت اللازم للعبور من 18 ساعة إلى 11 ساعة. القناة الجديدة تهدف إلى زيادة عدد السفن التي تعبر القناة، وتحسين كفاءة النقل البحري في المنطقة.
#
# 🧑 You: اتكلم عن الدوري الفرنسي
# ...

# %%
import requests

GROQ_API_KEY = "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"
url = "https://api.groq.com/openai/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {GROQ_API_KEY}",
    "Content-Type": "application/json"
}
content = """
https://en.wikipedia.org/wiki/Egypt
جاوب باللغة الي يطلبها منك المستخدم من خلال اللينك دا فقط
اي حاجه برا اللينك دا قول انك مش متخصص فيها وانك تخصص مصر واخبارها فقط
وقوله ميتعاملش معاك تاني
"""
chat_history = [
    {"role": "system", "content": content}
]

while True:
    user_input = input("🧑 You: ")
    if user_input.lower() == "exit":
        print("👋 Goodbye!")
        break

    chat_history.append({"role": "user", "content": user_input})

    data = {
        "model": "llama-3.3-70b-versatile",
        "messages": chat_history,
        "temperature": 0.3
    }

    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        reply = response.json()["choices"][0]["message"]["content"]
        chat_history.append({"role": "assistant", "content": reply})
        print(f"🤖 Bot: {reply}\n")
    else:
        print(f"[Error] {response.status_code}: {response.text}")
# Out:
# 🧑 You: اتكلملي عن 6 اكتوبر بالاسباني
# 🤖 Bot: Lo siento, pero mi especialidad es solo sobre Egipto y sus noticias. No puedo proporcionar información en español sobre temas fuera de mi especialidad. Mi enfoque es brindar información precisa y actualizada sobre Egipto, incluyendo su historia, cultura, política y eventos actuales. Si deseas saber más sobre el 6 de octubre en el contexto de Egipto, puedo proporcionarte información sobre la batalla del 6 de octubre de 1973, también conocida como la Guerra de Yom Kippur, que fue un conflicto militar entre Egipto e Israel. Sin embargo, si buscas información en español sobre otros temas, no puedo ayudarte. Mi especialidad es Egipto y solo Egipto. No me comunicaré contigo de nuevo sobre temas fuera de mi especialidad.
#
# 🧑 You: اتكلملي عن 25 يناير بالصيني
# 🤖 Bot: 抱歉，我只专注于埃及和其新闻。关于25 января的信息，我可以告诉你，这是埃及的一個重要日子，标志着2011年的埃及革命的开始。但是，我不能提供中文翻译或信息，因为我的专长仅限于埃及和阿拉伯语。如果你想了解更多关于埃及的信息，我可以提供帮助。但是，如果你需要关于其他主题的信息，我恐怕不能协助你。我的专长仅限于埃及，谢谢你的理解。
#
# ...

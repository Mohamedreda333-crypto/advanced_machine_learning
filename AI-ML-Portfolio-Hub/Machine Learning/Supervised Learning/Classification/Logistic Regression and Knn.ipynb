# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\PC\Downloads\gender_classification_v7.csv")

# %%
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
df.shape
# Out:
# (5001, 8)

# %%
df.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
df.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    2501
# Male      2500
# Name: count, dtype: int64

# %%
df.describe(include="O")
# Out:
#         gender
# count     5001
# unique       2
# top     Female
# freq      2501

# %%
plt.Figure(figsize=(6,4))
sns.kdeplot(df["forehead_width_cm"],fill = True ,color="blue")
plt.xlabel("Forehead Width (cm)")
plt.ylabel("Density")
plt.title("KDE Distribution of Forehead Width")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.kdeplot(df["forehead_height_cm"], fill=True, color='blue')
plt.xlabel("Forehead Height (cm)")
plt.ylabel("Density")
plt.title("KDE Distribution of Forehead Height")
plt.show()

# %%
df["long_hair"].value_counts()
# Out:
# long_hair
# 1    4349
# 0     652
# Name: count, dtype: int64

# %%
plt.Figure(figsize=(6,4))
df["long_hair"].value_counts().plot(kind="bar", color=['blue', 'orange'])
plt.xlabel("Long Hair (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Distribution of Long Hair")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"], rotation=0)
plt.show()

# %%
plt.figure(figsize=(6, 4))
df["nose_wide"].value_counts().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel("Nose Wide (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Distribution of Nose Wide")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"], rotation=0)
plt.show()

# %%
pd.DataFrame(df.groupby("gender")["nose_wide"].value_counts())
# Out:
#                   count
# gender nose_wide
# Female 0           2214
#        1            287
# Male   1           2183
#        0            317

# %%
pd.DataFrame(df.groupby("gender")["long_hair"].value_counts())
# Out:
#                   count
# gender long_hair
# Female 1           2184
#        0            317
# Male   1           2165
#        0            335

# %%
plt.figure(figsize=(6, 4))
df["nose_long"].value_counts().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel("Nose Long (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Distribution of Nose Long")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"], rotation=0)
plt.show()

# %%
pd.DataFrame(df.groupby("gender")["nose_long"].value_counts())
# Out:
#                   count
# gender nose_long
# Female 0           2161
#        1            340
# Male   1           2200
#        0            300

# %%
plt.figure(figsize=(6, 4))
df["lips_thin"].value_counts().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel("Lips Thin (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Distribution of Lips Thin")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"], rotation=0)
plt.show()

# %%
pd.DataFrame(df.groupby("gender")["lips_thin"].value_counts())
# Out:
#                   count
# gender lips_thin
# Female 0           2197
#        1            304
# Male   1           2162
#        0            338

# %%
plt.figure(figsize=(6, 4))
df["distance_nose_to_lip_long"].value_counts().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel("Distance Nose to Lip Long (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Distribution of Distance Nose to Lip Long")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"], rotation=0)
plt.show()

# %%
plt.figure(figsize=(6, 4))
df["gender"].value_counts().plot(kind='pie')
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.kdeplot(data=df, x="forehead_width_cm", hue="gender", fill=True,palette="tab10")
plt.xlabel("Forehead Width (cm)")
plt.ylabel("Density")
plt.title("KDE Distribution of Forehead Width by Gender")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.kdeplot(data=df, x="forehead_height_cm", hue="gender", fill=True)
plt.xlabel("Forehead Height (cm)")
plt.ylabel("Density")
plt.title("KDE Distribution of Forehead Height by Gender")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x="long_hair", hue="gender")
plt.xlabel("Long Hair (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Long Hair Distribution by Gender")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x="nose_wide", hue="gender")
plt.xlabel("Nose Wide (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Nose Wide Distribution by Gender")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x="nose_long", hue="gender")
plt.xlabel("Nose Long (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Nose Long Distribution by Gender")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x="lips_thin", hue="gender")
plt.xlabel("Lips Thin (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Lips Thin Distribution by Gender")
plt.xticks(ticks=[0, 1], labels=["No", "Yes"])
plt.show()

# %%
# Encoding
df["gender_encoded"] = df["gender"].map({"Male": 1, "Female": 0})

# %%
df["gender_encoded"]
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 4996    0
# 4997    0
# 4998    0
# 4999    0
# 5000    1
# Name: gender_encoded, Length: 5001, dtype: int64

# %%
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender  gender_encoded
# 0          1                          1    Male               1
# 1          1                          0  Female               0
# 2          1                          1    Male               1
# 3          1                          1    Male               1
# 4          0                          0  Female               0

# %%
corr_matrix = df.drop(columns=["gender"]).corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender',
#        'gender_encoded'],
#       dtype='object')

# %%
X = df.drop(columns=['gender','gender_encoded'])
y = df["gender_encoded"]

# %%
X.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long
# 0          1                          1
# 1          1                          0
# 2          1                          1
# 3          1                          1
# 4          0                          0

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 4996    0
# 4997    0
# 4998    0
# 4999    0
# 5000    1
# Name: gender_encoded, Length: 5001, dtype: int64

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
(X_train.shape, X_test.shape), (y_train.shape, y_test.shape)
# Out:
# (((4000, 7), (1001, 7)), ((4000,), (1001,)))

# %%
X_train
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 2771          1               12.7                 5.8          1          1
# 627           1               15.4                 6.9          1          1
# 1102          1               15.4                 6.9          1          1
# 1261          1               13.5                 6.3          1          0
# 1618          1               11.7                 5.1          0          0
# ...         ...                ...                 ...        ...        ...
# 2050          1               11.8                 6.2          0          1
# 570           1               12.4                 5.3          1          1
# 153           0               12.5                 6.8          1          1
# 190           1               13.7                 5.5          0          0
# 2194          1               12.5                 6.6          1          1
#
#       lips_thin  distance_nose_to_lip_long
# ...

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.964035964035964

# %%
accuracy_score(y_train, model.predict(X_train_scaled))
# Out:
# 0.9705

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn_model.predict(X_test_scaled)

# %%
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.967032967032967

# %%
accuracy_score(y_train, knn_model.predict(X_train_scaled))
# Out:
# 0.97475

# %%
df.head(1)
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
#
#    lips_thin  distance_nose_to_lip_long gender  gender_encoded
# 0          1                          1   Male               1

# %%
new_record = np.array([0,15,7,1,0,1,0,]).reshape(1, -1)
new_record
# Out:
# array([[ 0, 15,  7,  1,  0,  1,  0]])

# %%
new_record_scaled = scaler.transform(new_record)
new_record_scaled
# Out:
# array([[-2.57275098,  1.63946889,  1.92880846,  1.01359237, -1.02275892,
#          1.01207287, -0.99700449]])

# %%
# Knn Model
knn_model.predict(new_record_scaled)
# Out:
# array([1])

# %%
# Logistic Regression Model
model.predict(new_record_scaled)
# Out:
# array([1])
